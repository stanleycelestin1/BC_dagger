# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
fname = "BC_compare_iter10_06_2022_22_50_38.csv"
data = np.loadtxt(fname, delimiter=',')
x = data[:,0]
y = data[:,1]
plt.title("How does increasing the number of training iterations change performance?")
plt.xlabel("Training Iterations")
plt.ylabel("Policy Performance")
plt.plot(x,y)

# %%
fname = "BC_training_iterations10_17_2022_10_59_11.csv"
data = np.loadtxt(fname, delimiter=',')
x = data[:,0]
y = data[:,1]
plt.xlim([-1000, max(x)+0.5])
plt.ylim([50, max(y)+0.5])
plt.title("Loss (every 1000 batches of 100)")
plt.xlabel("Training Iteration i")
plt.ylabel("Loss")
plt.plot(x,y)

# 100000, 1000

# %%
fname = "BC_training_iterations10_17_2022_11_04_18.csv"
data = np.loadtxt(fname, delimiter=',')
x = data[:,0]
y = data[:,1]
# plt.xlim([-1000, max(x)+0.5])
# plt.ylim([50, max(y)+0.5])
plt.title("Loss (every 100 batches of 100)")
plt.xlabel("Training Iteration i")
plt.ylabel("Loss")
plt.plot(x,y)

# 10000, 100

# %%
# 10000, 1000
fname = "BC_training_iterations10_17_2022_11_06_49.csv"
data = np.loadtxt(fname, delimiter=',')
x = data[:,0]
y = data[:,1]
# plt.xlim([-1000, max(x)+0.5])
# plt.ylim([50, max(y)+0.5])
plt.title("Loss (every 1000 batches of 100)")
plt.xlabel("Training Iteration i")
plt.ylabel("Loss")
plt.plot(x,y)

# 10000, 100

# %%
data = [[0, 15.287435297894705], [1, 90.10809985802946], [2, 60.19936135475806], [3, 112.27496386417774], [4, 180.8387507233125], [5, 216.73897032392424], [6, 148.27778109253163], [7, 184.88762961658733], [8, 245.6729421095414], [9, 248.8383508946621], [10, 268.24474375064693], [11, 277.9412388876528], [12, 258.5408404672333], [13, 273.7439990738609], [14, 280.9509520892533], [15, 265.850545508573], [16, 274.4927071680331], [17, 258.6190548502128], [18, 288.78372916090944], [19, 274.94749107477406], [20, 275.2464454721103], [21, 280.4428380297214], [22, 281.1671382935801], [23, 288.28995916551503], [24, 285.1383198149209]]

# %%
data = np.array(data)

# %%
x = data[:,0]
y = data[:,1]

plt.title("DAgger performance improvements over iteration")
plt.xlabel("Dagger Iteration i")
plt.ylabel("Perfomance")
plt.plot(x,y)

# 10000, 100

# %%
data = [[8, -29.883546819502097, 4936], [9, -8.618659137755195, 5488], [10, -22.76671439207075, 6232], [11, -10.859536721086256, 6824], [12, -3.6147370993096404, 7312], [13, -19.800922870566744, 7976], [14, -21.283378967934677, 8664], [15, -24.784907071844536, 9264], [16, -24.864571097710574, 9856], [17, -17.866139588551853, 10424], [18, -17.690620015003944, 10992], [19, -22.54820801414493, 11528], [20, -25.56870423489516, 12192], [21, -6.712646164171037, 12640], [22, -11.28405792917004, 13160], [23, -17.410170680964047, 13848], [24, -18.343517712713425, 14352], [25, -21.014805322448883, 14816], [26, -20.514793044862742, 15296], [27, -19.427301988398312, 15936], [28, -21.345107976415427, 16584], [29, -21.49515269942823, 17040], [30, -11.268109993956788, 17488], [31, -21.67209041905635, 18152], [32, -27.858659739895565, 18720], [33, -13.147736957329153, 19240], [34, 2.8323628944483352, 19784]]
data = np.array(data)
x = data[:,0]
y = data[:,1]

# %%
plt.title("DAgger performance improvements over iteration")
plt.xlabel("Dagger Iteration i")
plt.ylabel("Perfomance")
plt.plot(x,y)

# 10000, 100
